# %%
import sys
import pandas as pd
import numpy as np
import random
import itertools
import logging
from collections import Counter

# %%
def generate_ngram(df, n, content='--both'):
    if content == '--both':
        ngram = np.zeros((len(df) - n + 1, n * 2))
        for i in range(len(df) - n + 1):
            nlength = np.array(df['note length'].iloc[i:i + n])
            pitch = np.array(df['pitch'].iloc[i:i + n])
            gram = np.append(nlength, pitch)
            ngram[i] = gram
    elif content == '--length':
        ngram = np.zeros((len(df) - n + 1, n))
        for i in range(len(df) - n + 1):
            nlength = np.array(df['note length'].iloc[i:i + n])
            ngram[i] = nlength
    elif content == "--pitch":
        ngram = np.zeros((len(df) - n + 1, n))
        for i in range(len(df) - n + 1):
            pitch = np.array(df['pitch'].iloc[i:i + n])
            ngram[i] = pitch
    return ngram

# %%
column_names = ['Id', 'Performer', 'Title', 'Inst.', 'Style', 'Year', 'Tempo', 'Number of Notes']
output_columns = ['Performer', 'Inst.', 'Style', 'Year', 'Tempo']
N = 3
profile_size = 1000

# %%
def get_profile(song_df, N):
    ngram = generate_ngram(song_df, N, '--both')
    c = Counter()
    for x in ngram:
        c[tuple([float(nr) for nr in x])] += 1
    return c

def similarity(type_profile, song_profile):
    new_type_profile = dict()
    new_song_profile = dict()
    for k in list(type_profile.keys()) + list(set(song_profile.keys()) - set(type_profile.keys())):
        new_type_profile[k] = type_profile[k] if k in type_profile else 0
        new_song_profile[k] = song_profile[k] if k in song_profile else 0
    return sum([4 - ((2 * (new_type_profile[k] - new_song_profile[k])) / 
                     (new_type_profile[k] + new_song_profile[k])) ** 2 for k in new_type_profile.keys()])

# %%
train = "./training-data-file-0.csv"

# %%
df = pd.read_csv(train, sep=';', index_col=0, names=column_names)
df['profile'] = df.apply(lambda row: get_profile(pd.read_csv("./unigram/" + str(row.name) + ".csv", index_col=0), N), axis=1)

# %%
type_profiles = pd.DataFrame(columns=['type', 'name', 'profile'])
for output_column in output_columns:  # For each output type (e.g. Performer, Year,…)…
    grouped = df.groupby(output_column)  # …group the rows by that output type…
    for name, group in grouped:
        profile = group.loc[:, 'profile'].sum()
        print("Before: profile size is", len(profile))
        flat_profile = list(profile.items())
        flat_profile = flat_profile[:profile_size]
        profile = Counter(dict(flat_profile))
        print("After: profile size is", len(profile))
        type_profiles = type_profiles.append({'type': output_column, 'name': name, 'profile': profile}, ignore_index=True)
# Out:
# Before: profile size is 2072
# After: profile size is 1000
# Before: profile size is 1349
# After: profile size is 1000
# Before: profile size is 1201
# After: profile size is 1000
# Before: profile size is 576
# After: profile size is 576
# Before: profile size is 2634
# After: profile size is 1000
# Before: profile size is 1917
# After: profile size is 1000
# Before: profile size is 943
# After: profile size is 943
# Before: profile size is 694
# After: profile size is 694
# Before: profile size is 1358
# After: profile size is 1000
# Before: profile size is 1558
# After: profile size is 1000
# Before: profile size is 2948
# After: profile size is 1000
# Before: profile size is 1276
# After: profile size is 1000
# Before: profile size is 2839
# After: profile size is 1000
# Before: profile size is 1197
# After: profile size is 1000
# Before: profile size is 1023
# After: profile size is 1000
# Before: profile size is 1178
# After: profile size is 1000
# Before: profile size is 1862
# After: profile size is 1000
# Before: profile size is 1915
# After: profile size is 1000
# Before: profile size is 2800
# After: profile size is 1000
# Before: profile size is 4146
# After: profile size is 1000
# Before: profile size is 1640
# After: profile size is 1000
# Before: profile size is 1550
# After: profile size is 1000
# Before: profile size is 1291
# After: profile size is 1000
# Before: profile size is 995
# After: profile size is 995
# Before: profile size is 393
# After: profile size is 393
# Before: profile size is 2263
# After: profile size is 1000
# Before: profile size is 924
# After: profile size is 924
# Before: profile size is 2192
# After: profile size is 1000
# Before: profile size is 1145
# After: profile size is 1000
# Before: profile size is 1005
# After: profile size is 1000
# Before: profile size is 2029
# After: profile size is 1000
# Before: profile size is 1839
# After: profile size is 1000
# Before: profile size is 2188
# After: profile size is 1000
# Before: profile size is 1444
# After: profile size is 1000
# Before: profile size is 1121
# After: profile size is 1000
# Before: profile size is 1777
# After: profile size is 1000
# Before: profile size is 10903
# After: profile size is 1000
# Before: profile size is 1124
# After: profile size is 1000
# Before: profile size is 1212
# After: profile size is 1000
# Before: profile size is 4173
# After: profile size is 1000
# Before: profile size is 1862
# After: profile size is 1000
# Before: profile size is 7952
# After: profile size is 1000
# Before: profile size is 24590
# After: profile size is 1000
# Before: profile size is 862
# After: profile size is 862
# Before: profile size is 5862
# After: profile size is 1000
# Before: profile size is 6491
# After: profile size is 1000
# Before: profile size is 2192
# After: profile size is 1000
# Before: profile size is 8630
# After: profile size is 1000
# Before: profile size is 21939
# After: profile size is 1000
# Before: profile size is 7725
# After: profile size is 1000
# Before: profile size is 393
# After: profile size is 393
# Before: profile size is 44
# After: profile size is 44
# Before: profile size is 161
# After: profile size is 161
# Before: profile size is 191
# After: profile size is 191
# Before: profile size is 350
# After: profile size is 350
# Before: profile size is 238
# After: profile size is 238
# Before: profile size is 283
# After: profile size is 283
# Before: profile size is 236
# After: profile size is 236
# Before: profile size is 393
# After: profile size is 393
# Before: profile size is 478
# After: profile size is 478
# Before: profile size is 2184
# After: profile size is 1000
# Before: profile size is 379
# After: profile size is 379
# Before: profile size is 887
# After: profile size is 887
# Before: profile size is 1002
# After: profile size is 1000
# Before: profile size is 1010
# After: profile size is 1000
# Before: profile size is 534
# After: profile size is 534
# Before: profile size is 2368
# After: profile size is 1000
# Before: profile size is 846
# After: profile size is 846
# Before: profile size is 2404
# After: profile size is 1000
# Before: profile size is 4515
# After: profile size is 1000
# Before: profile size is 181
# After: profile size is 181
# Before: profile size is 5345
# After: profile size is 1000
# Before: profile size is 352
# After: profile size is 352
# Before: profile size is 2132
# After: profile size is 1000
# Before: profile size is 430
# After: profile size is 430
# Before: profile size is 2487
# After: profile size is 1000
# Before: profile size is 4220
# After: profile size is 1000
# Before: profile size is 652
# After: profile size is 652
# Before: profile size is 1984
# After: profile size is 1000
# Before: profile size is 911
# After: profile size is 911
# Before: profile size is 419
# After: profile size is 419
# Before: profile size is 429
# After: profile size is 429
# Before: profile size is 826
# After: profile size is 826
# Before: profile size is 2851
# After: profile size is 1000
# Before: profile size is 679
# After: profile size is 679
# Before: profile size is 988
# After: profile size is 988
# Before: profile size is 1160
# After: profile size is 1000
# Before: profile size is 3155
# After: profile size is 1000
# Before: profile size is 971
# After: profile size is 971
# Before: profile size is 1808
# After: profile size is 1000
# Before: profile size is 2326
# After: profile size is 1000
# Before: profile size is 293
# After: profile size is 293
# Before: profile size is 2241
# After: profile size is 1000
# Before: profile size is 2084
# After: profile size is 1000
# Before: profile size is 1822
# After: profile size is 1000
# Before: profile size is 301
# After: profile size is 301
# Before: profile size is 155
# After: profile size is 155
# Before: profile size is 453
# After: profile size is 453
# Before: profile size is 523
# After: profile size is 523
# Before: profile size is 327
# After: profile size is 327
# Before: profile size is 582
# After: profile size is 582
# Before: profile size is 660
# After: profile size is 660
# Before: profile size is 121
# After: profile size is 121
# Before: profile size is 529
# After: profile size is 529
# Before: profile size is 544
# After: profile size is 544
# Before: profile size is 142
# After: profile size is 142
# Before: profile size is 176
# After: profile size is 176
# Before: profile size is 634
# After: profile size is 634
# Before: profile size is 302
# After: profile size is 302
# Before: profile size is 236
# After: profile size is 236
# Before: profile size is 265
# After: profile size is 265
# Before: profile size is 395
# After: profile size is 395
# Before: profile size is 181
# After: profile size is 181
# Before: profile size is 344
# After: profile size is 344
# Before: profile size is 534
# After: profile size is 534
# Before: profile size is 733
# After: profile size is 733
# Before: profile size is 124
# After: profile size is 124
# Before: profile size is 458
# After: profile size is 458
# Before: profile size is 311
# After: profile size is 311
# Before: profile size is 862
# After: profile size is 862
# Before: profile size is 126
# After: profile size is 126
# Before: profile size is 944
# After: profile size is 944
# Before: profile size is 403
# After: profile size is 403
# Before: profile size is 408
# After: profile size is 408
# Before: profile size is 141
# After: profile size is 141
# Before: profile size is 492
# After: profile size is 492
# Before: profile size is 430
# After: profile size is 430
# Before: profile size is 661
# After: profile size is 661
# Before: profile size is 224
# After: profile size is 224
# Before: profile size is 420
# After: profile size is 420
# Before: profile size is 445
# After: profile size is 445
# Before: profile size is 559
# After: profile size is 559
# Before: profile size is 419
# After: profile size is 419
# Before: profile size is 210
# After: profile size is 210
# Before: profile size is 1083
# After: profile size is 1000
# Before: profile size is 458
# After: profile size is 458
# Before: profile size is 179
# After: profile size is 179
# Before: profile size is 869
# After: profile size is 869
# Before: profile size is 203
# After: profile size is 203
# Before: profile size is 332
# After: profile size is 332
# Before: profile size is 336
# After: profile size is 336
# Before: profile size is 216
# After: profile size is 216
# Before: profile size is 363
# After: profile size is 363
# Before: profile size is 498
# After: profile size is 498
# Before: profile size is 188
# After: profile size is 188
# Before: profile size is 354
# After: profile size is 354
# Before: profile size is 889
# After: profile size is 889
# Before: profile size is 468
# After: profile size is 468
# Before: profile size is 390
# After: profile size is 390
# Before: profile size is 243
# After: profile size is 243
# Before: profile size is 667
# After: profile size is 667
# Before: profile size is 293
# After: profile size is 293
# Before: profile size is 112
# After: profile size is 112
# Before: profile size is 44
# After: profile size is 44
# Before: profile size is 111
# After: profile size is 111
# Before: profile size is 988
# After: profile size is 988
# Before: profile size is 114
# After: profile size is 114
# Before: profile size is 449
# After: profile size is 449
# Before: profile size is 352
# After: profile size is 352
# Before: profile size is 607
# After: profile size is 607
# Before: profile size is 644
# After: profile size is 644
# Before: profile size is 565
# After: profile size is 565
# Before: profile size is 417
# After: profile size is 417
# Before: profile size is 363
# After: profile size is 363
# Before: profile size is 295
# After: profile size is 295
# Before: profile size is 665
# After: profile size is 665
# Before: profile size is 554
# After: profile size is 554
# Before: profile size is 211
# After: profile size is 211
# Before: profile size is 429
# After: profile size is 429
# Before: profile size is 826
# After: profile size is 826
# Before: profile size is 107
# After: profile size is 107
# Before: profile size is 815
# After: profile size is 815
# Before: profile size is 497
# After: profile size is 497
# Before: profile size is 442
# After: profile size is 442
# Before: profile size is 164
# After: profile size is 164
# Before: profile size is 727
# After: profile size is 727
# Before: profile size is 555
# After: profile size is 555
# Before: profile size is 372
# After: profile size is 372
# Before: profile size is 404
# After: profile size is 404
# Before: profile size is 79
# After: profile size is 79
# Before: profile size is 220
# After: profile size is 220
# Before: profile size is 239
# After: profile size is 239
# Before: profile size is 83
# After: profile size is 83
# Before: profile size is 421
# After: profile size is 421
# Before: profile size is 141
# After: profile size is 141
# Before: profile size is 911
# After: profile size is 911
# Before: profile size is 254
# After: profile size is 254
# Before: profile size is 191
# After: profile size is 191
# Before: profile size is 651
# After: profile size is 651
# Before: profile size is 545
# After: profile size is 545
# Before: profile size is 490
# After: profile size is 490
# Before: profile size is 839
# After: profile size is 839
# Before: profile size is 163
# After: profile size is 163
# Before: profile size is 658
# After: profile size is 658
# Before: profile size is 577
# After: profile size is 577
# Before: profile size is 189
# After: profile size is 189
# Before: profile size is 761
# After: profile size is 761
# Before: profile size is 407
# After: profile size is 407
# Before: profile size is 309
# After: profile size is 309
# Before: profile size is 191
# After: profile size is 191
# Before: profile size is 269
# After: profile size is 269
# Before: profile size is 339
# After: profile size is 339
# Before: profile size is 362
# After: profile size is 362
# Before: profile size is 393
# After: profile size is 393
# Before: profile size is 648
# After: profile size is 648
# Before: profile size is 745
# After: profile size is 745
# Before: profile size is 664
# After: profile size is 664
# Before: profile size is 970
# After: profile size is 970
# Before: profile size is 303
# After: profile size is 303
# Before: profile size is 600
# After: profile size is 600
# Before: profile size is 253
# After: profile size is 253
# Before: profile size is 574
# After: profile size is 574
# Before: profile size is 340
# After: profile size is 340
# Before: profile size is 283
# After: profile size is 283
# Before: profile size is 510
# After: profile size is 510
# Before: profile size is 280
# After: profile size is 280
# Before: profile size is 161
# After: profile size is 161
# Before: profile size is 650
# After: profile size is 650
# Before: profile size is 1005
# After: profile size is 1000
# Before: profile size is 163
# After: profile size is 163
# Before: profile size is 211
# After: profile size is 211
# Before: profile size is 590
# After: profile size is 590
# Before: profile size is 1794
# After: profile size is 1000
# Before: profile size is 322
# After: profile size is 322
# Before: profile size is 159
# After: profile size is 159
# Before: profile size is 1015
# After: profile size is 1000
# Before: profile size is 995
# After: profile size is 995
# Before: profile size is 498
# After: profile size is 498
# Before: profile size is 551
# After: profile size is 551
# Before: profile size is 80
# After: profile size is 80
# Before: profile size is 191
# After: profile size is 191
# Before: profile size is 926
# After: profile size is 926
# Before: profile size is 706
# After: profile size is 706
# Before: profile size is 227
# After: profile size is 227
